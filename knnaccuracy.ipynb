# %% [markdown]
# # import pandas as pd
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler, OneHotEncoder
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.metrics import classification_report

# %%
###### import pandas as pd
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt

# Function to preprocess data
def preprocess_data(chunk):
    # Drop unnecessary columns
    chunk.drop(['nameOrig', 'nameDest'], axis=1, inplace=True)
    
    # Encode categorical variable 'type' using one-hot encoding
    enc = OneHotEncoder()
    type_encoded = enc.fit_transform(chunk[['type']])
    
    # Extracting feature names for the one-hot encoded column
    feature_names = enc.get_feature_names_out(['type'])
    
    # Convert encoded result to DataFrame and concatenate with original chunk
    type_encoded_df = pd.DataFrame(type_encoded.toarray(), columns=feature_names)
    chunk_processed = pd.concat([chunk.reset_index(drop=True), type_encoded_df], axis=1)
    
    # Drop the original 'type' column
    chunk_processed.drop(['type'], axis=1, inplace=True)
    
    return chunk_processed

# Function to process KNN chunks and calculate accuracies and AUC
def process_knn(file_path, chunk_size):
    knn_model = KNeighborsClassifier(n_neighbors=5)  # Example: K=5
    scaler = StandardScaler()
    
    train_accuracies = []
    test_accuracies = []
    auc_scores = []
    
    # Total counts for progress tracking
    total_chunks = 0
    total_samples = 0
    
    # Initialize StratifiedShuffleSplit
    splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
    
    for chunk in pd.read_csv(file_path, chunksize=chunk_size):
        chunk_processed = preprocess_data(chunk)
        
        X = chunk_processed.drop('isFraud', axis=1)
        y = chunk_processed['isFraud']
        
        total_chunks += 1
        total_samples += len(chunk)
        
        print(f"Processing KNN Chunk {total_chunks} with {len(chunk)} samples...")
        
        # Check if more than one class is present in the chunk
        if len(y.unique()) < 2:
            print(f"Skipping KNN training for Chunk {total_chunks} due to only one class present.")
            continue
        
        # Scale the features
        X_scaled = scaler.fit_transform(X)
        
        # Use StratifiedShuffleSplit to split the data
        for train_idx, test_idx in splitter.split(X_scaled, y):
            X_train, X_test = X_scaled[train_idx], X_scaled[test_idx]
            y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
        
        # Train the KNN model
        knn_model.fit(X_train, y_train)
        
        # Evaluate the model on train set
        train_accuracy = knn_model.score(X_train, y_train)
        train_accuracies.append(train_accuracy)
        
        # Evaluate the model on test set
        test_accuracy = knn_model.score(X_test, y_test)
        test_accuracies.append(test_accuracy)
        
        # Calculate AUC on test set if both classes are present
        if len(y_test.unique()) > 1:
            y_prob = knn_model.predict_proba(X_test)[:, 1]  # Probability of class 1 (fraud)
            auc = roc_auc_score(y_test, y_prob)
            auc_scores.append(auc)
        else:
            print(f"Skipping AUC calculation for Chunk {total_chunks} due to only one class present in y_test.")
    
    print(f"KNN: Processed {total_chunks} chunks with {total_samples} samples in total.")
    return train_accuracies, test_accuracies, auc_scores

# Function to plot KNN accuracies and AUC
def plot_knn_results(train_accuracies, test_accuracies, auc_scores):
    plt.figure(figsize=(12, 12))
    
    # Plot train and test accuracies
    plt.subplot(2, 1, 1)
    plt.plot(range(1, len(train_accuracies) + 1), train_accuracies, marker='o', linestyle='-', color='b', label='Train Accuracy')
    plt.plot(range(1, len(test_accuracies) + 1), test_accuracies, marker='o', linestyle='-', color='g', label='Test Accuracy')
    
    # Add labels and title
    plt.xlabel('Chunk Number')
    plt.ylabel('Accuracy')
    plt.title('KNN Model Accuracy')
    plt.xticks(range(1, len(train_accuracies) + 1))
    
    # Add legend and grid
    plt.legend()
    plt.grid(True)
    
    # Plot AUC scores
    plt.subplot(2, 1, 2)
    if auc_scores:
        plt.plot(range(1, len(auc_scores) + 1), auc_scores, marker='o', linestyle='-', color='r', label='AUC')
    
    # Add labels and title
    plt.xlabel('Chunk Number')
    plt.ylabel('AUC')
    plt.title('KNN Model AUC')
    plt.xticks(range(1, len(auc_scores) + 1))
    
    # Add legend and grid
    plt.legend()
    plt.grid(True)
    
    # Show plot
    plt.tight_layout()
    plt.show()

# Example usage
file_path = 'Synthetic_Financial_datasets_log.csv'  # Replace with your actual file path
chunk_size = 50000  # Adjust chunk size as needed

# Process KNN chunks and get train and test accuracies
knn_train_accuracies, knn_test_accuracies, knn_auc_scores = process_knn(file_path, chunk_size)

# Plot KNN results
plot_knn_results(knn_train_accuracies, knn_test_accuracies, knn_auc_scores)
# Out:
# Processing KNN Chunk 1 with 50000 samples...
# Processing KNN Chunk 2 with 50000 samples...
# Processing KNN Chunk 3 with 50000 samples...
# Processing KNN Chunk 4 with 50000 samples...
# Processing KNN Chunk 5 with 50000 samples...
# Processing KNN Chunk 6 with 50000 samples...
# Processing KNN Chunk 7 with 50000 samples...
# Processing KNN Chunk 8 with 50000 samples...
# Processing KNN Chunk 9 with 50000 samples...
# Processing KNN Chunk 10 with 50000 samples...
# Processing KNN Chunk 11 with 50000 samples...
# Processing KNN Chunk 12 with 50000 samples...
# Processing KNN Chunk 13 with 50000 samples...
# Processing KNN Chunk 14 with 50000 samples...
# Processing KNN Chunk 15 with 50000 samples...
# Processing KNN Chunk 16 with 50000 samples...
# Processing KNN Chunk 17 with 50000 samples...
# Processing KNN Chunk 18 with 50000 samples...
# Processing KNN Chunk 19 with 50000 samples...
# Processing KNN Chunk 20 with 50000 samples...
# Processing KNN Chunk 21 with 50000 samples...
# Processing KNN Chunk 22 with 50000 samples...
# Processing KNN Chunk 23 with 50000 samples...
# Processing KNN Chunk 24 with 50000 samples...
# Processing KNN Chunk 25 with 50000 samples...
# Processing KNN Chunk 26 with 50000 samples...
# Processing KNN Chunk 27 with 50000 samples...
# Processing KNN Chunk 28 with 50000 samples...
# Processing KNN Chunk 29 with 50000 samples...
# Processing KNN Chunk 30 with 50000 samples...
# Processing KNN Chunk 31 with 50000 samples...
# Processing KNN Chunk 32 with 50000 samples...
# Processing KNN Chunk 33 with 50000 samples...
# Processing KNN Chunk 34 with 50000 samples...
# Processing KNN Chunk 35 with 50000 samples...
# Processing KNN Chunk 36 with 50000 samples...
# Processing KNN Chunk 37 with 50000 samples...
# Processing KNN Chunk 38 with 50000 samples...
# Processing KNN Chunk 39 with 50000 samples...
# Processing KNN Chunk 40 with 50000 samples...
# Processing KNN Chunk 41 with 50000 samples...
# Processing KNN Chunk 42 with 50000 samples...
# Processing KNN Chunk 43 with 50000 samples...
# Processing KNN Chunk 44 with 50000 samples...
# Processing KNN Chunk 45 with 50000 samples...
# Processing KNN Chunk 46 with 50000 samples...
# Processing KNN Chunk 47 with 50000 samples...
# Processing KNN Chunk 48 with 50000 samples...
# Processing KNN Chunk 49 with 50000 samples...
# Processing KNN Chunk 50 with 50000 samples...
# Processing KNN Chunk 51 with 50000 samples...
# Processing KNN Chunk 52 with 50000 samples...
# Processing KNN Chunk 53 with 50000 samples...
# Processing KNN Chunk 54 with 50000 samples...
# Processing KNN Chunk 55 with 50000 samples...
# Processing KNN Chunk 56 with 50000 samples...
# Processing KNN Chunk 57 with 50000 samples...
# Processing KNN Chunk 58 with 50000 samples...
# Processing KNN Chunk 59 with 50000 samples...
# Processing KNN Chunk 60 with 50000 samples...
# Processing KNN Chunk 61 with 50000 samples...
# Processing KNN Chunk 62 with 50000 samples...
# Processing KNN Chunk 63 with 50000 samples...
# Processing KNN Chunk 64 with 50000 samples...
# Processing KNN Chunk 65 with 50000 samples...
# Processing KNN Chunk 66 with 50000 samples...
# Processing KNN Chunk 67 with 50000 samples...
# Processing KNN Chunk 68 with 50000 samples...
# Processing KNN Chunk 69 with 50000 samples...
# Processing KNN Chunk 70 with 50000 samples...
# Processing KNN Chunk 71 with 50000 samples...
# Processing KNN Chunk 72 with 50000 samples...
# Processing KNN Chunk 73 with 50000 samples...
# Processing KNN Chunk 74 with 50000 samples...
# Processing KNN Chunk 75 with 50000 samples...
# Processing KNN Chunk 76 with 50000 samples...
# Processing KNN Chunk 77 with 50000 samples...
# Processing KNN Chunk 78 with 50000 samples...
# Processing KNN Chunk 79 with 50000 samples...
# Processing KNN Chunk 80 with 50000 samples...
# Processing KNN Chunk 81 with 50000 samples...
# Processing KNN Chunk 82 with 50000 samples...
# Processing KNN Chunk 83 with 50000 samples...
# Processing KNN Chunk 84 with 50000 samples...
# Processing KNN Chunk 85 with 50000 samples...
# Processing KNN Chunk 86 with 50000 samples...
# Processing KNN Chunk 87 with 50000 samples...
# Processing KNN Chunk 88 with 50000 samples...
# Processing KNN Chunk 89 with 50000 samples...
# Processing KNN Chunk 90 with 50000 samples...
# Processing KNN Chunk 91 with 50000 samples...
# Processing KNN Chunk 92 with 50000 samples...
# Processing KNN Chunk 93 with 50000 samples...
# Processing KNN Chunk 94 with 50000 samples...
# Processing KNN Chunk 95 with 50000 samples...
# Processing KNN Chunk 96 with 50000 samples...
# Processing KNN Chunk 97 with 50000 samples...
# Processing KNN Chunk 98 with 50000 samples...
# Processing KNN Chunk 99 with 50000 samples...
# Processing KNN Chunk 100 with 50000 samples...
# Processing KNN Chunk 101 with 50000 samples...
# Processing KNN Chunk 102 with 50000 samples...
# Processing KNN Chunk 103 with 50000 samples...
# Processing KNN Chunk 104 with 50000 samples...
# Processing KNN Chunk 105 with 50000 samples...
# Processing KNN Chunk 106 with 50000 samples...
# Processing KNN Chunk 107 with 50000 samples...
# Processing KNN Chunk 108 with 50000 samples...
# Processing KNN Chunk 109 with 50000 samples...
# Processing KNN Chunk 110 with 50000 samples...
# Processing KNN Chunk 111 with 50000 samples...
# Processing KNN Chunk 112 with 50000 samples...
# Processing KNN Chunk 113 with 50000 samples...
# Processing KNN Chunk 114 with 50000 samples...
# Processing KNN Chunk 115 with 50000 samples...
# Processing KNN Chunk 116 with 50000 samples...
# Processing KNN Chunk 117 with 50000 samples...
# Processing KNN Chunk 118 with 50000 samples...
# Processing KNN Chunk 119 with 50000 samples...
# Processing KNN Chunk 120 with 50000 samples...
# Processing KNN Chunk 121 with 50000 samples...
# Processing KNN Chunk 122 with 50000 samples...
# Processing KNN Chunk 123 with 50000 samples...
# Processing KNN Chunk 124 with 50000 samples...
# Processing KNN Chunk 125 with 50000 samples...
# Processing KNN Chunk 126 with 50000 samples...
# Processing KNN Chunk 127 with 50000 samples...
# Processing KNN Chunk 128 with 12620 samples...
# KNN: Processed 128 chunks with 6362620 samples in total.
